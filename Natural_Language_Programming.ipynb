# %%
#NLP is a field concerned with the ability of computer understanding, analyzing , manipulating and genrate human language
#Pythong doesn't know any words. All it sees is a string of characters
# Spam filter , Auto text detection, auto correct
#NLP is used for sentiment Analysis, Topic modeling, senetence segmentation, text classification
#NLP extracts all the information from a block of text that is relevant to computer understanding the language
#

# %%
#NLTK used for natural language processing
#Installing NLTK
# !pip install -U nltk

# %%
import nltk

# %%
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> 1
#     Error loading 1: Package '1' not found in index
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> u
#
# Nothing to update.
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> c
#
# Data Server:
#   - URL: <https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml>
# ...

# %%
dir(nltk)
# Out:
# ['ARLSTem',
#  'ARLSTem2',
#  'AbstractLazySequence',
#  'AffixTagger',
#  'AlignedSent',
#  'Alignment',
#  'AnnotationTask',
#  'ApplicationExpression',
#  'Assignment',
#  'BigramAssocMeasures',
#  'BigramCollocationFinder',
#  'BigramTagger',
#  'BinaryMaxentFeatureEncoding',
#  'BlanklineTokenizer',
#  'BllipParser',
#  'BottomUpChartParser',
#  'BottomUpLeftCornerChartParser',
#  'BottomUpProbabilisticChartParser',
#  'Boxer',
#  'BrillTagger',
#  'BrillTaggerTrainer',
#  'CFG',
#  'CRFTagger',
#  'CfgReadingCommand',
#  'ChartParser',
#  'ChunkParserI',
#  'ChunkScore',
#  'Cistem',
#  'ClassifierBasedPOSTagger',
#  'ClassifierBasedTagger',
#  'ClassifierI',
#  'ConcordanceIndex',
#  'ConditionalExponentialClassifier',
#  'ConditionalFreqDist',
#  'ConditionalProbDist',
#  'ConditionalProbDistI',
#  'ConfusionMatrix',
#  'ContextIndex',
#  'ContextTagger',
#  'ContingencyMeasures',
#  'CoreNLPDependencyParser',
#  'CoreNLPParser',
#  'Counter',
#  'CrossValidationProbDist',
# ...

# %%
#pos_tag is used for parts of speech tagging
#

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stopwords.words('english')[0:5]
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['i', 'me', 'my', 'myself', 'we']

# %%
# stop words are removed as they don't provide any meaning information for analysis and to remove noise
# These are sentiment neutral
# how to read semi structured data
# unstructured can be binary data, no rows indication, no delimiters
#

# %%
# import files to google collab from local drive
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-495d7120-a2ae-4714-8661-c78323e3045c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-495d7120-a2ae-4714-8661-c78323e3045c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
rawdata = open('SMSSpamCollection.tsv').read()
print(rawdata[0:500])
# Out:
# ham	I've been searching for the right words to thank you for this breather. I promise i wont take your help for granted and will fulfil my promise. You have been wonderful and a blessing at all times.
# spam	Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's
# ham	Nah I don't think he goes to usf, he lives around here though
# ham	Even my brother is not like to speak with me. They treat me like aid

# %%
parsedata = rawdata.replace('\t','\n').split('\n')
parsedata[0:5]
# Out:
# ['ham',
#  "I've been searching for the right words to thank you for this breather. I promise i wont take your help for granted and will fulfil my promise. You have been wonderful and a blessing at all times.",
#  'spam',
#  "Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's",
#  'ham']

# %%
labellist = parsedata[0::2]
textlist = parsedata[1::2]
print(labellist[0:5])
print(textlist[0:5])
# Out:
# ['ham', 'spam', 'ham', 'ham', 'ham']
# ["I've been searching for the right words to thank you for this breather. I promise i wont take your help for granted and will fulfil my promise. You have been wonderful and a blessing at all times.", "Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's", "Nah I don't think he goes to usf, he lives around here though", 'Even my brother is not like to speak with me. They treat me like aids patent.', 'I HAVE A DATE ON SUNDAY WITH WILL!!']

# %%
# check the key and values are equal
print(len(labellist))
print(len(textlist))
# Out:
# 5571
# 5570

# %%
import pandas as pd
fullcorpus = pd.DataFrame({'label':labellist[:-1],'text':textlist})
fullcorpus.head()
# Out:
#   label                                               text
# 0   ham  I've been searching for the right words to tha...
# 1  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 2   ham  Nah I don't think he goes to usf, he lives aro...
# 3   ham  Even my brother is not like to speak with me. ...
# 4   ham                I HAVE A DATE ON SUNDAY WITH WILL!!

# %%
dataset = pd.read_csv('SMSSpamCollection.tsv',sep='\t',header=None)
dataset.head()
# Out:
#       0                                                  1
# 0   ham  I've been searching for the right words to tha...
# 1  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 2   ham  Nah I don't think he goes to usf, he lives aro...
# 3   ham  Even my brother is not like to speak with me. ...
# 4   ham                I HAVE A DATE ON SUNDAY WITH WILL!!

# %%
dataset.columns = ['label','text']
dataset.head()
# Out:
#   label                                               text
# 0   ham  I've been searching for the right words to tha...
# 1  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 2   ham  Nah I don't think he goes to usf, he lives aro...
# 3   ham  Even my brother is not like to speak with me. ...
# 4   ham                I HAVE A DATE ON SUNDAY WITH WILL!!

# %%
dataset.shape
# Out:
# (5568, 2)

# %%
print("Out of {} rows, {} are spam and {} are ham".format(len(dataset), len(dataset[dataset['label'] == 'spam']), len(dataset[dataset['label'] == 'ham'])))
# Out:
# Out of 5568 rows, 746 are spam and 4822 are ham

# %%
# checking the missing values
print (dataset['label'].isnull().sum())
print (dataset['text'].isnull().sum())
# Out:
# 0
# 0

# %%
# regular expression
# serach pattern

# %%
#'nlp','[j-q]', search patterns
#  returns single character at a time
# searches for strings longer than one character: '[j-q]'+
# regular expression are used for finding white space
# Used for passowrd criteria
# for url
# file names
# document scraping
#

# %%
import re
re_test = 'This is a made up string to test 2 different regex methods'
re_test_messy = 'This      is a made up     string to test 2    different regex methods'
re_test_messy1 = 'This-is-a-made/up.string*to>>>>test----2""""""different~regex-methods'

# %%
#splitting sentences into list of words
re.split('\s',re_test)
# Out:
# ['This',
#  'is',
#  'a',
#  'made',
#  'up',
#  'string',
#  'to',
#  'test',
#  '2',
#  'different',
#  'regex',
#  'methods']

# %%
re.split('\s',re_test_messy)
# Out:
# ['This',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'is',
#  'a',
#  'made',
#  'up',
#  '',
#  '',
#  '',
#  '',
#  'string',
#  'to',
#  'test',
#  '2',
#  '',
#  '',
#  '',
#  'different',
#  'regex',
#  'methods']

# %%
#looking for one or more white spaces
re.split('\s+',re_test_messy)
# Out:
# ['This',
#  'is',
#  'a',
#  'made',
#  'up',
#  'string',
#  'to',
#  'test',
#  '2',
#  'different',
#  'regex',
#  'methods']

# %%
re.split('\s+',re_test_messy1)
# Out:
# ['This-is-a-made/up.string*to>>>>test----2""""""different~regex-methods']

# %%
#searching for any non word characters
re.split('\W+',re_test_messy)
# Out:
# ['This',
#  'is',
#  'a',
#  'made',
#  'up',
#  'string',
#  'to',
#  'test',
#  '2',
#  'different',
#  'regex',
#  'methods']

# %%
#insteading splitting with white or space or special characters, let's find the text we want
re.findall('\S+',re_test)
# Out:
# ['This',
#  'is',
#  'a',
#  'made',
#  'up',
#  'string',
#  'to',
#  'test',
#  '2',
#  'different',
#  'regex',
#  'methods']

# %%
re.findall('\S+',re_test_messy)
# Out:
# ['This',
#  'is',
#  'a',
#  'made',
#  'up',
#  'string',
#  'to',
#  'test',
#  '2',
#  'different',
#  'regex',
#  'methods']

# %%
re.split('\s+',re_test_messy1)
# Out:
# ['This-is-a-made/up.string*to>>>>test----2""""""different~regex-methods']

# %%
re.split('\W+',re_test_messy1)
# Out:
# ['This',
#  'is',
#  'a',
#  'made',
#  'up',
#  'string',
#  'to',
#  'test',
#  '2',
#  'different',
#  'regex',
#  'methods']

# %%
# tokenization
# findALL: LOOKS FOR THE words that we need
# split: looks for a separator

# %%
# useful reg expression for tokenizing
# '\w' or '\W' : for words
# '\S' or '\s': for whitespaces

# %%
pep8_test = 'I try to follow PEP8 guidelines'
pep7_test = 'I try to follow PEP7 guidelines'
peep8_test = 'I try to follow PEEP8 guidelines'

# %%
import re
re.findall('[a-z]+',pep8_test)
# the above looks for only small letters
# Out:
# ['try', 'to', 'follow', 'guidelines']

# %%
# we need to look for capital letters
re.findall('[A-Z]+',pep8_test)
# Out:
# ['I', 'PEP']

# %%
re.findall('[A-Z]+[0-9]+',pep8_test)
# Out:
# ['PEP8']

# %%
re.sub('[A-Z]+[0-9]+','PEP8 Python Styleguide',pep8_test)
# Out:
# 'I try to follow PEP8 Python Styleguide guidelines'

# %%
# Implementing a pipeline to clean the text
# Remove punctuation. tokenization, remove stop words, lemmatize/stem
#

# %%
import pandas as pd
pd.set_option('display.max_colwidth',100)
data = pd.read_csv('SMSSpamCollection.tsv',sep='\t',header=None)
data.columns = ['label','text']
data.head()
# Out:
#   label  \
# 0   ham
# 1  spam
# 2   ham
# 3   ham
# 4   ham
#
#                                                                                                   text
# 0  I've been searching for the right words to thank you for this breather. I promise i wont take yo...
# 1  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 2                                        Nah I don't think he goes to usf, he lives around here though
# 3                        Even my brother is not like to speak with me. They treat me like aids patent.
# 4                                                                  I HAVE A DATE ON SUNDAY WITH WILL!!

# %%
from google.colab import files
uploaded = files.upload()

# %%
data_cleaned = pd.read_csv('SMSSpamCollection_cleaned.tsv',sep='\t')
data_cleaned.head()

# %%
# remove punctuation
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punct(text):
  text_nopunct = "".join([char for char in text if char not in string.punctuation])
  return text_nopunct
data['text_clean'] = data['text'].apply(lambda x: remove_punct(x))
data.head()
# Out:
#   label  \
# 0   ham
# 1  spam
# 2   ham
# 3   ham
# 4   ham
#
#                                                                                                   text  \
# 0  I've been searching for the right words to thank you for this breather. I promise i wont take yo...
# 1  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 2                                        Nah I don't think he goes to usf, he lives around here though
# 3                        Even my brother is not like to speak with me. They treat me like aids patent.
# 4                                                                  I HAVE A DATE ON SUNDAY WITH WILL!!
#
#                                                                                             text_clean
# 0  Ive been searching for the right words to thank you for this breather I promise i wont take your...
# ...

# %%
# tokenization
import re
def tokenize(text):
  tokens = re.split('\W+',text)
  return tokens
data['text_tokenized'] = data['text_clean'].apply(lambda x: tokenize(x.lower()))
data.head()
# Out:
#   label  \
# 0   ham
# 1  spam
# 2   ham
# 3   ham
# 4   ham
#
#                                                                                                   text  \
# 0  I've been searching for the right words to thank you for this breather. I promise i wont take yo...
# 1  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 2                                        Nah I don't think he goes to usf, he lives around here though
# 3                        Even my brother is not like to speak with me. They treat me like aids patent.
# 4                                                                  I HAVE A DATE ON SUNDAY WITH WILL!!
#
#                                                                                             text_clean  \
# 0  Ive been searching for the right words to thank you for this breather I promise i wont take your...
# ...

# %%
# remove stop words
import nltk
nltk.download('stopwords')
stopword = nltk.corpus.stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
 #remove stop words
 def remove_stopwords(tokenized_list):
   text = [word for word in tokenized_list if word not in stopword]
   return text
data['text_nostop'] = data['text_tokenized'].apply(lambda x: remove_stopwords(x))
data.head()
# Out:
#   label  \
# 0   ham
# 1  spam
# 2   ham
# 3   ham
# 4   ham
#
#                                                                                                   text  \
# 0  I've been searching for the right words to thank you for this breather. I promise i wont take yo...
# 1  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 2                                        Nah I don't think he goes to usf, he lives around here though
# 3                        Even my brother is not like to speak with me. They treat me like aids patent.
# 4                                                                  I HAVE A DATE ON SUNDAY WITH WILL!!
#
#                                                                                             text_clean  \
# 0  Ive been searching for the right words to thank you for this breather I promise i wont take your...
# ...

# %%
# stemming
#choopin off the end of the word and keeping only the base
# porter stemmer
# snowball stemmer
#lancaster stem
# Reg ex stemmer

# %%
#import nltk and porter stemmer
import nltk
ps = nltk.PorterStemmer()
dir(ps)
# Out:
# ['MARTIN_EXTENSIONS',
#  'NLTK_EXTENSIONS',
#  'ORIGINAL_ALGORITHM',
#  '__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_apply_rule_list',
#  '_contains_vowel',
#  '_ends_cvc',
#  '_ends_double_consonant',
#  '_has_positive_measure',
#  '_is_consonant',
#  '_measure',
#  '_replace_suffix',
#  '_step1a',
#  '_step1b',
#  '_step1c',
#  '_step2',
#  '_step3',
#  '_step4',
#  '_step5a',
#  '_step5b',
#  'mode',
#  'pool',
#  'stem',
#  'vowels']

# %%
print(ps.stem('grow'))
print(ps.stem('growing'))
print(ps.stem('grows'))
# Out:
# grow
# grow
# grow

# %%
print(ps.stem('run'))
print(ps.stem('running'))
print(ps.stem('runner'))
# Out:
# run
# run
# runner

# %%
import pandas as pd
import re
import string
pd.set_option('display.max_colwidth',100)
data = pd.read_csv('SMSSpamCollection.tsv',sep='\t',header=None)
data.columns = ['label','text']
data.head()
# Out:
#   label  \
# 0   ham
# 1  spam
# 2   ham
# 3   ham
# 4   ham
#
#                                                                                                   text
# 0  I've been searching for the right words to thank you for this breather. I promise i wont take yo...
# 1  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 2                                        Nah I don't think he goes to usf, he lives around here though
# 3                        Even my brother is not like to speak with me. They treat me like aids patent.
# 4                                                                  I HAVE A DATE ON SUNDAY WITH WILL!!

# %%
# cleaning up the text
def clean_text(text):
  text = "".join([word for word in text if word not in string.punctuation])
  tokens = re.split('\W+',text)
  text = [word for word in tokens if word not in stopword]
  return
  data['text_nostop'] = data['text_tokenized'].apply(lambda x: remove_stopwords(x))

# %%
import string
import re
import pandas as pd
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# Sample data
data = pd.DataFrame({'text_column': ["This is a sample text. It needs cleaning!"]})

# Define stopwords
stopword = stopwords.words('english')

# Initialize PorterStemmer
ps = PorterStemmer()

def clean_text(text):
    text = "".join([char for char in text if char not in string.punctuation])
    tokens = re.split('\W+', text)
    text = [word for word in tokens if word.lower() not in stopword]
    return text

def remove_stopwords(text):
    return [word for word in text if word.lower() not in stopword]

def stemming(tokenized_text):
    text = [ps.stem(word) for word in tokenized_text]
    return text

# Apply the clean_text function to the text column
data['text_tokenized'] = data['text_column'].apply(lambda x: clean_text(x))

# Apply the remove_stopwords function to the tokenized text
data['text_nostop'] = data['text_tokenized'].apply(lambda x: remove_stopwords(x))

# Apply the stemming function to the text without stopwords
data['text_stemmed'] = data['text_nostop'].apply(lambda x: stemming(x))

# Display the first few rows of the DataFrame
print(data.head())
# Out:
#                                  text_column                   text_tokenized  \
# 0  This is a sample text. It needs cleaning!  [sample, text, needs, cleaning]
#
#                        text_nostop                text_stemmed
# 0  [sample, text, needs, cleaning]  [sampl, text, need, clean]

# %%
#lemmatizing
import nltk
nltk.download('wordnet')
wn = nltk.WordNetLemmatizer()
ps = nltk.PorterStemmer()
def lemmatizing(tokenized_text):
  text = [wn.lemmatize(word) for word in tokenized_text]
  return text
  data['text_lemmatized'] = data['text_nostop'].apply(lambda x: lemmatizing(x))
  data.head()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
#vectorizing
# process of encoding text as integers to create feature vectors
# feature vector is an n dimensional vector of numerical features that represent some object

# %%
# import files from local drive
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-984aae96-c487-4410-abc3-4fb159431b75" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-984aae96-c487-4410-abc3-4fb159431b75">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# vectorization count
import pandas as pd
import re
import string
pd.set_option('display.max_colwidth',100)
data = pd.read_csv('SMSSpamCollection.tsv',sep='\t',header=None)
data.columns = ['label','text']
data.head()
# Out:
#   label  \
# 0   ham
# 1  spam
# 2   ham
# 3   ham
# 4   ham
#
#                                                                                                   text
# 0  I've been searching for the right words to thank you for this breather. I promise i wont take yo...
# 1  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 2                                        Nah I don't think he goes to usf, he lives around here though
# 3                        Even my brother is not like to speak with me. They treat me like aids patent.
# 4                                                                  I HAVE A DATE ON SUNDAY WITH WILL!!

# %%
#remove punctuation, tokenize, remove stop words and stem
def clean_text(text):
  text = "".join([word for word in text if word not in string.punctuation])
  tokens = re.split('\W+',text)
  text = [word for word in tokens if word not in stopword]
  return text

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vect = CountVectorizer(analyzer=clean_text)
X_counts = count_vect.fit_transform(data['text'])
print(X_counts.shape)
# Out:
# (5568, 11519)

# %%
print(count_vect.get_feature_names_out())
# Out:
# ['' '0' '008704050406' ... 'ü' 'üll' '〨ud']
